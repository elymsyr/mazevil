# %%
from google.colab import drive
drive.mount('/content/gdrive')
# !rm -rf /content/sample_data
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ## Before you start
#
# Let's make sure that we have access to GPU. We can use `nvidia-smi` command to do that. In case of any problems navigate to `Edit` -> `Notebook settings` -> `Hardware accelerator`, set it to `GPU`, and then click `Save`.

# %%
# !pip install ultralytics

# %%
# !nvidia-smi
# Out:
# Sun Aug 11 13:14:31 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   55C    P8              10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %% [markdown]
# ## Now Start

# %%
# !mkdir /content/images
# !unzip -q /content/images.zip -d /content/images
# !rm -r /content/images.zip
# Out:
# mkdir: cannot create directory ‘/content/images’: File exists

# %% [markdown]
# ## Custom Training

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=/content/images/custom_data.yaml epochs=100 imgsz=640 plots=True
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8s.pt to 'yolov8s.pt'...
# 100% 21.5M/21.5M [00:00<00:00, 254MB/s]
# Ultralytics YOLOv8.2.75 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# engine/trainer: task=detect, mode=train, model=yolov8s.pt, data=/content/images/custom_data.yaml, epochs=100, time=None, patience=100, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf'...
# 100% 755k/755k [00:00<00:00, 16.9MB/s]
# Overriding model.yaml nc=80 with nc=15
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.block.C2f             [768, 512, 1]
#  22        [15, 18, 21]  1   2121853  ultralytics.nn.modules.head.Detect           [15, [128, 256, 512]]
# Model summary: 225 layers, 11,141,405 parameters, 11,141,389 gradients, 28.7 GFLOPs
#
# Transferred 349/355 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train', view at http://localhost:6006/
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8n.pt to 'yolov8n.pt'...
# 100% 6.25M/6.25M [00:00<00:00, 103MB/s]
# AMP: checks passed ✅
# train: Scanning /content/images/train/labels... 314 images, 1 backgrounds, 0 corrupt: 100% 314/314 [00:00<00:00, 2026.13it/s]
# train: New cache created: /content/images/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# val: Scanning /content/images/val/labels... 79 images, 0 backgrounds, 0 corrupt: 100% 79/79 [00:00<00:00, 1515.64it/s]
# val: New cache created: /content/images/val/labels.cache
# Plotting labels to runs/detect/train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000526, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# TensorBoard: model graph visualization added ✅
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/detect/train
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      4.31G      1.459      5.139      1.081         83        640: 100% 20/20 [00:11<00:00,  1.71it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:04<00:00,  1.46s/it]
#                    all         79        357      0.561      0.182      0.175     0.0986
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      4.24G      1.081      1.762     0.9185         93        640: 100% 20/20 [00:05<00:00,  3.46it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:01<00:00,  2.93it/s]
#                    all         79        357      0.615      0.515      0.493       0.33
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      4.24G      1.005      1.144     0.8969         82        640: 100% 20/20 [00:08<00:00,  2.41it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:01<00:00,  1.61it/s]
#                    all         79        357      0.811       0.67      0.751      0.528
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      4.36G     0.9749      0.949     0.8997         84        640: 100% 20/20 [00:05<00:00,  3.52it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  3.26it/s]
#                    all         79        357      0.805      0.805      0.905      0.629
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      4.18G       0.94     0.8271     0.8863        104        640: 100% 20/20 [00:07<00:00,  2.54it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:02<00:00,  1.45it/s]
#                    all         79        357      0.841       0.88      0.931      0.675
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      4.32G     0.9531     0.7511      0.894        112        640: 100% 20/20 [00:05<00:00,  3.57it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  3.42it/s]
#                    all         79        357      0.867      0.939      0.949      0.677
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      4.37G     0.9051     0.6941      0.884        146        640: 100% 20/20 [00:08<00:00,  2.43it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:01<00:00,  1.68it/s]
#                    all         79        357      0.866      0.951      0.953      0.685
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      4.35G      0.918     0.6569     0.8771         83        640: 100% 20/20 [00:05<00:00,  3.60it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  3.33it/s]
#                    all         79        357      0.888      0.908      0.949      0.665
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      4.17G     0.9447     0.6626     0.8875         91        640: 100% 20/20 [00:07<00:00,  2.71it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:02<00:00,  1.24it/s]
#                    all         79        357      0.872      0.932      0.948      0.681
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      4.36G     0.9117     0.6303     0.8753        101        640: 100% 20/20 [00:06<00:00,  3.33it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:01<00:00,  2.93it/s]
#                    all         79        357      0.929      0.952      0.959      0.696
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      4.32G     0.8636     0.5935      0.874        103        640: 100% 20/20 [00:09<00:00,  2.20it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:01<00:00,  2.29it/s]
#                    all         79        357      0.932      0.958      0.957      0.707
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      4.37G     0.8488     0.5483     0.8667        109        640: 100% 20/20 [00:05<00:00,  3.46it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  3.53it/s]
#                    all         79        357      0.933      0.966      0.962      0.716
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100      4.35G     0.8462     0.5511     0.8731        110        640: 100% 20/20 [00:08<00:00,  2.37it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:01<00:00,  1.78it/s]
#                    all         79        357      0.916      0.966       0.97      0.723
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100      4.36G     0.8591     0.5713     0.8735         63        640: 100% 20/20 [00:05<00:00,  3.59it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  3.08it/s]
#                    all         79        357       0.91      0.969      0.959      0.696
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100      4.16G     0.8288     0.5579     0.8666        138        640: 100% 20/20 [00:08<00:00,  2.49it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:01<00:00,  1.57it/s]
#                    all         79        357      0.897      0.953      0.961      0.717
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100      4.19G     0.8445     0.5332     0.8609         70        640: 100% 20/20 [00:05<00:00,  3.55it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  4.00it/s]
#                    all         79        357      0.895      0.969      0.964      0.731
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100      4.32G     0.8308     0.5073     0.8596         66        640: 100% 20/20 [00:08<00:00,  2.47it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:01<00:00,  1.75it/s]
#                    all         79        357      0.937      0.966      0.964      0.723
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100      4.37G     0.8315      0.534     0.8668         82        640: 100% 20/20 [00:05<00:00,  3.59it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  3.56it/s]
#                    all         79        357       0.94      0.949      0.964      0.727
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100      4.36G     0.8191      0.513     0.8581        103        640: 100% 20/20 [00:07<00:00,  2.76it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:02<00:00,  1.50it/s]
#                    all         79        357      0.935      0.948      0.958      0.716
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/100      4.19G     0.8135     0.5148     0.8591        106        640: 100% 20/20 [00:06<00:00,  3.31it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  3.71it/s]
#                    all         79        357      0.931      0.965      0.956      0.724
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/100      4.19G     0.8142      0.495     0.8621        101        640: 100% 20/20 [00:07<00:00,  2.64it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:02<00:00,  1.49it/s]
#                    all         79        357      0.921      0.959      0.959       0.72
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/100      4.34G      0.801     0.4872     0.8593         81        640: 100% 20/20 [00:05<00:00,  3.38it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  3.91it/s]
#                    all         79        357      0.938      0.955      0.962      0.733
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/100      4.36G     0.8027     0.5039     0.8638        100        640: 100% 20/20 [00:06<00:00,  3.03it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:01<00:00,  1.75it/s]
#                    all         79        357      0.942      0.963      0.966      0.731
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/100       4.2G     0.8068     0.4983     0.8609         80        640: 100% 20/20 [00:06<00:00,  3.06it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  3.59it/s]
#                    all         79        357      0.919      0.923      0.953      0.731
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/100      4.36G     0.7835     0.4756     0.8582         83        640: 100% 20/20 [00:06<00:00,  3.09it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:01<00:00,  1.78it/s]
#                    all         79        357      0.923      0.953      0.962      0.734
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/100      4.17G     0.8013     0.4773     0.8565        118        640: 100% 20/20 [00:06<00:00,  2.99it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  3.32it/s]
#                    all         79        357       0.91      0.968      0.963      0.727
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/100      4.16G     0.7543     0.4559     0.8469         81        640: 100% 20/20 [00:05<00:00,  3.39it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:01<00:00,  1.87it/s]
#                    all         79        357      0.925      0.949      0.967      0.741
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/100       4.2G     0.7845     0.4607     0.8563         98        640: 100% 20/20 [00:07<00:00,  2.74it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  3.34it/s]
#                    all         79        357      0.899      0.968      0.957      0.717
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/100      4.19G     0.7806     0.4554     0.8494         60        640: 100% 20/20 [00:05<00:00,  3.40it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:01<00:00,  2.03it/s]
#                    all         79        357       0.94      0.957      0.964      0.729
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/100      4.32G     0.7696     0.4597     0.8441         82        640: 100% 20/20 [00:07<00:00,  2.61it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  3.44it/s]
#                    all         79        357      0.939      0.953       0.96       0.73
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/100      4.41G     0.7922      0.462     0.8543         83        640: 100% 20/20 [00:05<00:00,  3.56it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:01<00:00,  2.42it/s]
#                    all         79        357      0.939      0.966      0.961      0.744
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/100      4.32G     0.7642     0.4406     0.8478        100        640: 100% 20/20 [00:08<00:00,  2.48it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  3.78it/s]
#                    all         79        357      0.919      0.971      0.963      0.741
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/100      4.37G      0.752     0.4465     0.8432        110        640: 100% 20/20 [00:05<00:00,  3.39it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  4.06it/s]
#                    all         79        357      0.941      0.967      0.959      0.737
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      34/100      4.33G     0.7682     0.4397     0.8542         70        640: 100% 20/20 [00:08<00:00,  2.44it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  3.20it/s]
#                    all         79        357      0.947      0.971      0.965      0.731
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      35/100      4.36G     0.7473     0.4293     0.8468         95        640: 100% 20/20 [00:05<00:00,  3.50it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  3.36it/s]
#                    all         79        357      0.934      0.967      0.963      0.735
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      36/100      4.36G     0.7381     0.4313     0.8423         85        640: 100% 20/20 [00:08<00:00,  2.33it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  3.29it/s]
#                    all         79        357      0.929      0.975      0.964      0.733
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      37/100      4.32G     0.7201     0.4375     0.8459         66        640: 100% 20/20 [00:05<00:00,  3.57it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  3.68it/s]
#                    all         79        357      0.947      0.964      0.962       0.73
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      38/100      4.32G     0.7429     0.4351     0.8481         93        640: 100% 20/20 [00:08<00:00,  2.26it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  3.51it/s]
#                    all         79        357       0.94      0.972      0.961      0.723
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      39/100      4.38G     0.7348     0.4352     0.8386         76        640: 100% 20/20 [00:05<00:00,  3.59it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  3
0.747
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/100      4.32G     0.5534     0.3184     0.8128         86        640: 100% 20/20 [00:07<00:00,  2.63it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  3.71it/s]
#                    all         79        357      0.944      0.978      0.975       0.75
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/100      4.37G     0.5541     0.3178     0.8061         91        640: 100% 20/20 [00:05<00:00,  3.49it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:01<00:00,  2.27it/s]
#                    all         79        357      0.948      0.976      0.971      0.738
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/100      4.36G     0.5508     0.3131     0.8089        138        640: 100% 20/20 [00:08<00:00,  2.45it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  3.49it/s]
#                    all         79        357      0.949      0.974      0.973      0.745
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/100      4.17G     0.5295     0.2983     0.8066         58        640: 100% 20/20 [00:05<00:00,  3.55it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  3.84it/s]
#                    all         79        357       0.95      0.974      0.977      0.744
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/100      4.19G     0.5376     0.3077       0.81        132        640: 100% 20/20 [00:08<00:00,  2.39it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  3.25it/s]
#                    all         79        357       0.95      0.971      0.974      0.744
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/100      4.15G      0.543      0.313     0.8107         34        640: 100% 20/20 [00:08<00:00,  2.31it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:01<00:00,  1.72it/s]
#                    all         79        357      0.939      0.978      0.976      0.743
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/100      4.18G     0.5341     0.3047     0.8055         44        640: 100% 20/20 [00:06<00:00,  2.86it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  3.78it/s]
#                    all         79        357      0.946      0.967      0.975      0.737
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/100      4.18G     0.5201     0.2943     0.8103         47        640: 100% 20/20 [00:05<00:00,  3.58it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:01<00:00,  1.95it/s]
#                    all         79        357      0.944      0.964      0.974      0.738
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/100      4.34G     0.5115     0.2902     0.8032         48        640: 100% 20/20 [00:07<00:00,  2.71it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  3.67it/s]
#                    all         79        357      0.946      0.963      0.977      0.737
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/100      4.34G     0.4926     0.2852     0.8057         44        640: 100% 20/20 [00:05<00:00,  3.54it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:01<00:00,  2.10it/s]
#                    all         79        357      0.944      0.961      0.978      0.734
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/100      4.34G     0.4932     0.2839     0.8024         47        640: 100% 20/20 [00:08<00:00,  2.43it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  3.51it/s]
#                    all         79        357      0.945       0.96      0.976      0.735
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/100      4.15G     0.4921     0.2801     0.8007         34        640: 100% 20/20 [00:05<00:00,  3.61it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  3.61it/s]
#                    all         79        357      0.943      0.962      0.974      0.736
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/100      4.31G     0.4851     0.2818     0.8006         50        640: 100% 20/20 [00:08<00:00,  2.26it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  3.99it/s]
#                    all         79        357      0.944      0.963      0.973       0.74
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/100      4.31G     0.4805     0.2788     0.7983         37        640: 100% 20/20 [00:05<00:00,  3.62it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  3.76it/s]
#                    all         79        357      0.944      0.965      0.971      0.741
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100      4.33G     0.4771     0.2758     0.7985         58        640: 100% 20/20 [00:08<00:00,  2.46it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:01<00:00,  1.54it/s]
#                    all         79        357      0.943      0.967      0.971      0.741
#
# 100 epochs completed in 0.256 hours.
# Optimizer stripped from runs/detect/train/weights/last.pt, 22.5MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 22.5MB
#
# Validating runs/detect/train/weights/best.pt...
# Ultralytics YOLOv8.2.75 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11,131,389 parameters, 0 gradients, 28.5 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:02<00:00,  1.39it/s]
#                    all         79        357      0.931      0.977      0.979      0.755
#             enemy_slug         40         85      0.937          1      0.985      0.687
#         enemy_slug_big         13         28      0.912      0.929      0.958      0.751
#               trap_off         55         97      0.906       0.99      0.989      0.887
#                trap_on         14         20      0.862          1      0.975       0.88
#         enemy_skeleton         13         20      0.907          1      0.958      0.655
#   enemy_skeleton_shoot          4          4          1      0.977      0.995      0.574
#                   door          7          7          1      0.933      0.995      0.856
#              trap_door         22         23      0.876       0.92      0.899       0.72
#                   gold          5         21      0.954          1      0.995      0.672
#          treasury_open         17         18      0.945          1      0.995      0.772
#         treasury_close          5          5      0.922          1      0.995      0.895
#       treasury_monster         14         14       0.96      0.929       0.99      0.714
#                    key          6          6       0.99          1      0.995      0.704
#        enemy_slug_boss          9          9      0.868          1      0.984      0.808
# Speed: 0.1ms preprocess, 2.7ms inference, 0.0ms loss, 2.2ms postprocess per image
# Results saved to runs/detect/train
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %%
# !ls /content/runs/detect/train/
# Out:
# args.yaml					    R_curve.png		 val_batch0_labels.jpg
# confusion_matrix_normalized.png			    results.csv		 val_batch0_pred.jpg
# confusion_matrix.png				    results.png		 val_batch1_labels.jpg
# events.out.tfevents.1723382166.3ffec5af63ce.1328.0  train_batch0.jpg	 val_batch1_pred.jpg
# F1_curve.png					    train_batch1800.jpg  val_batch2_labels.jpg
# labels_correlogram.jpg				    train_batch1801.jpg  val_batch2_pred.jpg
# labels.jpg					    train_batch1802.jpg  weights
# P_curve.png					    train_batch1.jpg
# PR_curve.png					    train_batch2.jpg

# %%
Image(filename=f'/content/runs/detect/train/confusion_matrix.png', width=600)

# %%
Image(filename=f'/content/runs/detect/train/results.png', width=600)

# %%
Image(filename=f'/content/runs/detect/train/val_batch0_pred.jpg', width=600)

# %% [markdown]
# ## Validate Custom Model

# %%
# !yolo task=detect mode=val model=/content/runs/detect/train/weights/best.pt data=/content/images/custom_data.yaml
# Out:
# Ultralytics YOLOv8.2.75 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11,131,389 parameters, 0 gradients, 28.5 GFLOPs
# val: Scanning /content/images/val/labels.cache... 79 images, 0 backgrounds, 0 corrupt: 100% 79/79 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 5/5 [00:05<00:00,  1.10s/it]
#                    all         79        357      0.931      0.977      0.979      0.757
#             enemy_slug         40         85      0.937          1      0.985      0.688
#         enemy_slug_big         13         28      0.912      0.929      0.958      0.751
#               trap_off         55         97      0.906       0.99      0.988      0.885
#                trap_on         14         20      0.862          1      0.975      0.879
#         enemy_skeleton         13         20      0.907          1      0.958      0.647
#   enemy_skeleton_shoot          4          4          1      0.977      0.995      0.596
#                   door          7          7          1      0.933      0.995      0.856
#              trap_door         22         23      0.876       0.92      0.899      0.713
#                   gold          5         21      0.954          1      0.995      0.678
#          treasury_open         17         18      0.945          1      0.995      0.798
#         treasury_close          5          5      0.922          1      0.995      0.895
#       treasury_monster         14         14       0.96      0.929       0.99      0.717
#                    key          6          6       0.99          1      0.995      0.692
#        enemy_slug_boss          9          9      0.868          1      0.984      0.808
# Speed: 1.0ms preprocess, 8.2ms inference, 0.0ms loss, 8.6ms postprocess per image
# Results saved to runs/detect/val2
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
from google.colab import files
# !rm -r /content/gdrive/MyDrive/YOLO/runs
# !cp -r /content/runs /content/gdrive/MyDrive/YOLO/
# !zip -r /content/gdrive/MyDrive/YOLO/runs.zip /content/runs
files.download('/content/gdrive/MyDrive/YOLO/runs.zip')

# %% [markdown]
# ## Inference with Custom Model

# %%
# !mkdir /content/test
# !unzip -q /content/test.zip -d /content/test
# !rm -r /content/test.zip

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train/weights/best.pt conf=0.25 source=/content/test save=True
# Out:
# Ultralytics YOLOv8.2.75 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11,131,389 parameters, 0 gradients, 28.5 GFLOPs
#
# image 1/6 /content/test/screenshot_539.png: 320x640 1 enemy_slug, 2 trap_offs, 1 door, 75.2ms
# image 2/6 /content/test/screenshot_567.png: 320x640 3 enemy_slug_bigs, 3 trap_offs, 1 enemy_skeleton, 1 enemy_skeleton_shoot, 1 trap_door, 10.5ms
# image 3/6 /content/test/screenshot_649.png: 320x640 1 enemy_slug_big, 2 trap_offs, 2 trap_ons, 5 enemy_skeletons, 4 enemy_skeleton_shoots, 1 trap_door, 5 golds, 10.6ms
# image 4/6 /content/test/screenshot_657.png: 320x640 1 trap_off, 2 trap_ons, 5 enemy_skeletons, 1 trap_door, 2 golds, 10.4ms
# image 5/6 /content/test/screenshot_927.png: 320x640 3 enemy_slug_bigs, 1 trap_door, 1 enemy_slug_boss, 10.4ms
# image 6/6 /content/test/screenshot_937.png: 320x640 1 enemy_slug, 1 enemy_slug_boss, 10.4ms
# Speed: 1.7ms preprocess, 21.3ms inference, 104.3ms postprocess per image at shape (1, 3, 320, 640)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# **NOTE:** Let's take a look at few results.

# %%
import glob,os
from IPython.display import Image, display

# Define the base path where the folders are located
base_path = '/content/runs/detect/'

# List all directories that start with 'predict' in the base path
subfolders = [os.path.join(base_path, d) for d in os.listdir(base_path)
              if os.path.isdir(os.path.join(base_path, d)) and d.startswith('predict')]

# Find the latest folder by modification time
latest_folder = max(subfolders, key=os.path.getmtime)

image_paths = glob.glob(f'{latest_folder}/*.png')[:3]

# Display each image
for image_path in image_paths:
    display(Image(filename=image_path, width=600))
    print("\n")
